# %%
import spacy
import json
from spacy import displacy

# %% [markdown]
# ### load test set

# %%
datas = open("../autism.json/autism.json").read()

# %%
len(datas)
# Out:
# 390142358

# %%
# datas[8:1495]

# %% [markdown]
# load model

# %%
nlp2 = spacy.load("models/fs_normal/epoch_15")

# %%
doc = nlp2(unicode(datas[8:2000]))

# %%
print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
# Out:
# ('Entities', [(u'DRD4', u'GENE'), (u'DAT', u'GENE'), (u'COMT', u'GENE'), (u'MAOA', u'GENE'), (u'schizophrenia', u'DISEASE')])

# %%
datas[8:2000]
# Out:
# 'Current efforts to study the genetic underpinnings of higher brain functions have been lacking appropriate phenotypes to describe cognition. One of the problems is that many cognitive concepts for which there is a single word (e.g. attention) have been shown to be related to several anatomical networks. Recently, we have developed an Attention Network Test (ANT) that provides a separate measure for each of three anatomically defined attention networks. In this study we have measured the efficiency of neural networks related to aspects of attention using the ANT in a population of 200 adult subjects. We then examined genetic polymorphisms in four candidate genes (DRD4, DAT, COMT and MAOA) that have been shown to contribute to the risk of developing various psychiatric disorders where attention is disrupted. We find modest associations of several polymorphisms with the efficiency of executive attention but not with overall performance measures such as reaction time. These results suggest that genetic variation may underlie inter-subject variation in the efficiency of executive attention. This study also shows that genetic influences on executive attention may be specific to certain anatomical networks rather than affecting performance in a global or non-specific manner. Lastly, this study further validates the ANT as an endophenotypic assay suitable for assessing how genes influence certain anatomical networks that may be disrupted in various psychiatric disorders.", "raw": "An inability to select and maintain mental focus is commonly observed in many heritable psychiatric disorders. For example, patients with schizophrenia exhibit difficulties in sensorimotor gating [ unaffected first degree relatives of schizophrenic patients show impaired performance in assays of auditory attention and working memory [ Consistent with this notion, attentional performance in normal subjects appears to be influenced by genetic factors. Studies using the Continuous Performance'

# %%
[(t.text, t.ent_type_ if t.ent_type_ else "default") for t in doc]
# Out:
# [(u'Current', 'default'),
#  (u'efforts', 'default'),
#  (u'to', 'default'),
#  (u'study', 'default'),
#  (u'the', 'default'),
#  (u'genetic', 'default'),
#  (u'underpinnings', 'default'),
#  (u'of', 'default'),
#  (u'higher', 'default'),
#  (u'brain', 'default'),
#  (u'functions', 'default'),
#  (u'have', 'default'),
#  (u'been', 'default'),
#  (u'lacking', 'default'),
#  (u'appropriate', 'default'),
#  (u'phenotypes', 'default'),
#  (u'to', 'default'),
#  (u'describe', 'default'),
#  (u'cognition', 'default'),
#  (u'.', 'default'),
#  (u'One', 'default'),
#  (u'of', 'default'),
#  (u'the', 'default'),
#  (u'problems', 'default'),
#  (u'is', 'default'),
#  (u'that', 'default'),
#  (u'many', 'default'),
#  (u'cognitive', 'default'),
#  (u'concepts', 'default'),
#  (u'for', 'default'),
#  (u'which', 'default'),
#  (u'there', 'default'),
#  (u'is', 'default'),
#  (u'a', 'default'),
#  (u'single', 'default'),
#  (u'word', 'default'),
#  (u'(', 'default'),
#  (u'e.g.', 'default'),
#  (u'attention', 'default'),
#  (u')', 'default'),
#  (u'have', 'default'),
#  (u'been', 'default'),
#  (u'shown', 'default'),
#  (u'to', 'default'),
#  (u'be', 'default'),
#  (u'related', 'default'),
#  (u'to', 'default'),
#  (u'several', 'default'),
#  (u'anatomical', 'default'),
#  (u'networks', 'default'),
#  (u'.', 'default'),
#  (u'Recently', 'default'),
#  (u',', 'default'),
#  (u'we', 'default'),
#  (u'have', 'default'),
#  (u'developed', 'default'),
#  (u'an', 'default'),
#  (u'Attention', 'default'),
#  (u'Network', 'default'),
#  (u'Test', 'default'),
#  (u'(', 'default'),
#  (u'ANT', 'default'),
#  (u')', 'default'),
#  (u'that', 'default'),
#  (u'provides', 'default'),
#  (u'a', 'default'),
#  (u'separate', 'default'),
#  (u'measure', 'default'),
#  (u'for', 'default'),
#  (u'each', 'default'),
#  (u'of', 'default'),
#  (u'three', 'default'),
#  (u'anatomically', 'default'),
#  (u'defined', 'default'),
#  (u'attention', 'default'),
#  (u'networks', 'default'),
#  (u'.', 'default'),
#  (u'In', 'default'),
#  (u'this', 'default'),
#  (u'study', 'default'),
#  (u'we', 'default'),
#  (u'have', 'default'),
#  (u'measured', 'default'),
#  (u'the', 'default'),
#  (u'efficiency', 'default'),
#  (u'of', 'default'),
#  (u'neural', 'default'),
#  (u'networks', 'default'),
#  (u'related', 'default'),
#  (u'to', 'default'),
#  (u'aspects', 'default'),
#  (u'of', 'default'),
#  (u'attention', 'default'),
#  (u'using', 'default'),
#  (u'the', 'default'),
#  (u'ANT', 'default'),
#  (u'in', 'default'),
#  (u'a', 'default'),
#  (u'population', 'default'),
#  (u'of', 'default'),
#  (u'200', 'default'),
#  (u'adult', 'default'),
#  (u'subjects', 'default'),
#  (u'.', 'default'),
#  (u'We', 'default'),
#  (u'then', 'default'),
#  (u'examined', 'default'),
#  (u'genetic', 'default'),
#  (u'polymorphisms', 'default'),
#  (u'in', 'default'),
#  (u'four', 'default'),
#  (u'candidate', 'default'),
#  (u'genes', 'default'),
#  (u'(', 'default'),
#  (u'DRD4', u'GENE'),
#  (u',', 'default'),
#  (u'DAT', u'GENE'),
#  (u',', 'default'),
#  (u'COMT', u'GENE'),
#  (u'and', 'default'),
#  (u'MAOA', u'GENE'),
#  (u')', 'default'),
#  (u'that', 'default'),
#  (u'have', 'default'),
#  (u'been', 'default'),
#  (u'shown', 'default'),
#  (u'to', 'default'),
#  (u'contribute', 'default'),
#  (u'to', 'default'),
#  (u'the', 'default'),
#  (u'risk', 'default'),
#  (u'of', 'default'),
#  (u'developing', 'default'),
#  (u'various', 'default'),
#  (u'psychiatric', 'default'),
#  (u'disorders', 'default'),
#  (u'where', 'default'),
#  (u'attention', 'default'),
#  (u'is', 'default'),
#  (u'disrupted', 'default'),
#  (u'.', 'default'),
#  (u'We', 'default'),
#  (u'find', 'default'),
#  (u'modest', 'default'),
#  (u'associations', 'default'),
#  (u'of', 'default'),
#  (u'several', 'default'),
#  (u'polymorphisms', 'default'),
#  (u'with', 'default'),
#  (u'the', 'default'),
#  (u'efficiency', 'default'),
#  (u'of', 'default'),
#  (u'executive', 'default'),
#  (u'attention', 'default'),
#  (u'but', 'default'),
#  (u'not', 'default'),
#  (u'with', 'default'),
#  (u'overall', 'default'),
#  (u'performance', 'default'),
#  (u'measures', 'default'),
#  (u'such', 'default'),
#  (u'as', 'default'),
#  (u'reaction', 'default'),
#  (u'time', 'default'),
#  (u'.', 'default'),
#  (u'These', 'default'),
#  (u'results', 'default'),
#  (u'suggest', 'default'),
#  (u'that', 'default'),
#  (u'genetic', 'default'),
#  (u'variation', 'default'),
#  (u'may', 'default'),
#  (u'underlie', 'default'),
#  (u'inter', 'default'),
#  (u'-', 'default'),
#  (u'subject', 'default'),
#  (u'variation', 'default'),
#  (u'in', 'default'),
#  (u'the', 'default'),
#  (u'efficiency', 'default'),
#  (u'of', 'default'),
#  (u'executive', 'default'),
#  (u'attention', 'default'),
#  (u'.', 'default'),
#  (u'This', 'default'),
#  (u'study', 'default'),
#  (u'also', 'default'),
#  (u'shows', 'default'),
#  (u'that', 'default'),
#  (u'genetic', 'default'),
#  (u'influences', 'default'),
#  (u'on', 'default'),
#  (u'executive', 'default'),
#  (u'attention', 'default'),
#  (u'may', 'default'),
#  (u'be', 'default'),
#  (u'specific', 'default'),
#  (u'to', 'default'),
#  (u'certain', 'default'),
#  (u'anatomical', 'default'),
#  (u'networks', 'default'),
#  (u'rather', 'default'),
#  (u'than', 'default'),
#  (u'affecting', 'default'),
#  (u'performance', 'default'),
#  (u'in', 'default'),
#  (u'a', 'default'),
#  (u'global', 'default'),
#  (u'or', 'default'),
#  (u'non', 'default'),
#  (u'-', 'default'),
#  (u'specific', 'default'),
#  (u'manner', 'default'),
#  (u'.', 'default'),
#  (u'Lastly', 'default'),
#  (u',', 'default'),
#  (u'this', 'default'),
#  (u'study', 'default'),
#  (u'further', 'default'),
#  (u'validates', 'default'),
#  (u'the', 'default'),
#  (u'ANT', 'default'),
#  (u'as', 'default'),
#  (u'an', 'default'),
#  (u'endophenotypic', 'default'),
#  (u'assay', 'default'),
#  (u'suitable', 'default'),
#  (u'for', 'default'),
#  (u'assessing', 'default'),
#  (u'how', 'default'),
#  (u'genes', 'default'),
#  (u'influence', 'default'),
#  (u'certain', 'default'),
#  (u'anatomical', 'default'),
#  (u'networks', 'default'),
#  (u'that', 'default'),
#  (u'may', 'default'),
#  (u'be', 'default'),
#  (u'disrupted', 'default'),
#  (u'in', 'default'),
#  (u'various', 'default'),
#  (u'psychiatric', 'default'),
#  (u'disorders', 'default'),
#  (u'.', 'default'),
#  (u'"', 'default'),
#  (u',', 'default'),
#  (u'"', 'default'),
#  (u'raw', 'default'),
#  (u'"', 'default'),
#  (u':', 'default'),
#  (u'"', 'default'),
#  (u'An', 'default'),
#  (u'inability', 'default'),
#  (u'to', 'default'),
#  (u'select', 'default'),
#  (u'and', 'default'),
#  (u'maintain', 'default'),
#  (u'mental', 'default'),
#  (u'focus', 'default'),
#  (u'is', 'default'),
#  (u'commonly', 'default'),
#  (u'observed', 'default'),
#  (u'in', 'default'),
#  (u'many', 'default'),
#  (u'heritable', 'default'),
#  (u'psychiatric', 'default'),
#  (u'disorders', 'default'),
#  (u'.', 'default'),
#  (u'For', 'default'),
#  (u'example', 'default'),
#  (u',', 'default'),
#  (u'patients', 'default'),
#  (u'with', 'default'),
#  (u'schizophrenia', u'DISEASE'),
#  (u'exhibit', 'default'),
#  (u'difficulties', 'default'),
#  (u'in', 'default'),
#  (u'sensorimotor', 'default'),
#  (u'gating', 'default'),
#  (u'[', 'default'),
#  (u'unaffected', 'default'),
#  (u'first', 'default'),
#  (u'degree', 'default'),
#  (u'relatives', 'default'),
#  (u'of', 'default'),
#  (u'schizophrenic', 'default'),
#  (u'patients', 'default'),
#  (u'show', 'default'),
#  (u'impaired', 'default'),
#  (u'performance', 'default'),
#  (u'in', 'default'),
#  (u'assays', 'default'),
#  (u'of', 'default'),
#  (u'auditory', 'default'),
#  (u'attention', 'default'),
#  (u'and', 'default'),
#  (u'working', 'default'),
#  (u'memory', 'default'),
#  (u'[', 'default'),
#  (u'Consistent', 'default'),
#  (u'with', 'default'),
#  (u'this', 'default'),
#  (u'notion', 'default'),
#  (u',', 'default'),
#  (u'attentional', 'default'),
#  (u'performance', 'default'),
#  (u'in', 'default'),
#  (u'normal', 'default'),
#  (u'subjects', 'default'),
#  (u'appears', 'default'),
#  (u'to', 'default'),
#  (u'be', 'default'),
#  (u'influenced', 'default'),
#  (u'by', 'default'),
#  (u'genetic', 'default'),
#  (u'factors', 'default'),
#  (u'.', 'default'),
#  (u'Studies', 'default'),
#  (u'using', 'default'),
#  (u'the', 'default'),
#  (u'Continuous', 'default'),
#  (u'Performance', 'default')]

# %%
# displacy.render(doc, style='ent', jupyter=True)

# %%
# nlp = spacy.load('en')
# doc = nlp(u'This is a sentence.')
# displacy.serve(doc, style='ent')
